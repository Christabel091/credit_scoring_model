# %%
import pandas as pd
file_path = "../data/train.csv"
df = pd.read_csv(file_path)
coln = ["Customer_ID","Month","Name","SSN","Occupation"]
df.drop(columns=coln, inplace=True)
# Out:
# C:\Users\obinw\AppData\Local\Temp\ipykernel_115784\156041801.py:3: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#        ID   Age Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0  0x1602    23      19114.12            1824.843333                  3
# 1  0x1603    23      19114.12                    NaN                  3
# 2  0x1604  -500      19114.12                    NaN                  3
# 3  0x1605    23      19114.12                    NaN                  3
# 4  0x1606    23      19114.12            1824.843333                  3
#
#    Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                4              3           4
# 1                4              3           4
# 2                4              3           4
# 3                4              3           4
# 4                4              3           4
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...                   -1
# ...

# %%
df.to_csv('modified_dataset.csv', index=False)

# %%
color_map = {"Good" : 2, "Standard" : 1, "Poor" : 0}
df["Credit_Score"] = df["Credit_Score"].map(color_map)

# %%
df.head()
# Out:
#        ID   Age Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0  0x1602    23      19114.12            1824.843333                  3
# 1  0x1603    23      19114.12                    NaN                  3
# 2  0x1604  -500      19114.12                    NaN                  3
# 3  0x1605    23      19114.12                    NaN                  3
# 4  0x1606    23      19114.12            1824.843333                  3
#
#    Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                4              3           4
# 1                4              3           4
# 2                4              3           4
# 3                4              3           4
# 4                4              3           4
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...                   -1
# ...

# %%
df.to_csv('modified_dataset.csv', index=False)

# %%
del(df["ID"])

# %%
df['ID'] = df.index + 1

# %%
df["ID"].value_counts()
# Out:
# ID
# 1         1
# 66651     1
# 66673     1
# 66672     1
# 66671     1
#          ..
# 33332     1
# 33331     1
# 33330     1
# 33329     1
# 100000    1
# Name: count, Length: 100000, dtype: int64

# %%
df.head()
# Out:
#     Age Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0    23      19114.12            1824.843333                  3
# 1    23      19114.12                    NaN                  3
# 2  -500      19114.12                    NaN                  3
# 3    23      19114.12                    NaN                  3
# 4    23      19114.12            1824.843333                  3
#
#    Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                4              3           4
# 1                4              3           4
# 2                4              3           4
# 3                4              3           4
# 4                4              3           4
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...                   -1
# ...

# %%
df[0] = df["ID"]

# %%
df.head()
# Out:
#     Age Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0    23      19114.12            1824.843333                  3
# 1    23      19114.12                    NaN                  3
# 2  -500      19114.12                    NaN                  3
# 3    23      19114.12                    NaN                  3
# 4    23      19114.12            1824.843333                  3
#
#    Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                4              3           4
# 1                4              3           4
# 2                4              3           4
# 3                4              3           4
# 4                4              3           4
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...                   -1
# ...

# %%
del(df[0])

# %%
df.head()
# Out:
#     Age Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0    23      19114.12            1824.843333                  3
# 1    23      19114.12                    NaN                  3
# 2  -500      19114.12                    NaN                  3
# 3    23      19114.12                    NaN                  3
# 4    23      19114.12            1824.843333                  3
#
#    Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                4              3           4
# 1                4              3           4
# 2                4              3           4
# 3                4              3           4
# 4                4              3           4
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...                   -1
# ...

# %%
df.to_csv('modified_dataset.csv', index=False)

# %%
pip install sklearn

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


# Example: Label Encoding for a single column
# Replace '_' with a specific value for missing data (if applicable)
df['Payment_Behaviour'] = df['Payment_Behaviour'].fillna('Unknown')  # Example for handling missing values
# Out:
# ----------------------------------------------------------------------
# ModuleNotFoundError                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from sklearn.preprocessing import LabelEncoder, OneHotEncoder
#       4 # Example: Label Encoding for a single column
#       5 # Replace '_' with a specific value for missing data (if applicable)
#       6 df['Payment_Behaviour'] = df['Payment_Behaviour'].fillna('Unknown')  # Example for handling missing values
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
label_encoder = LabelEncoder()
df['Payment_Behaviour_LabelEncoded'] = label_encoder.fit_transform(df['Payment_Behaviour'])

# %%
# Example: One-Hot Encoding for a column with multiple categories
# Split the string values into separate columns
df['Type_of_Loan'] = df['Type_of_Loan'].str.split(', ')
# Use OneHotEncoder to convert the column with multiple categories into a separate columns
one_hot_encoder = OneHotEncoder(sparse = False)
encoded_types = one_hot_encoder.fit_transform(df['Type_of_Loan'].str.split(', ))
df = df.drop('Type_of_Loan', axis=1)
