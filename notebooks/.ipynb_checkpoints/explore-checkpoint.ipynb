# %%
#genereal exploration
import pandas as pd
import matplotlib.pyplot as plt
# Relative path example
file_path = '../Data/test.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#        ID Customer_ID      Month             Name  Age          SSN  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24_  821-00-0265
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0  Scientist      19114.12            1824.843333                  3  ...
# 1  Scientist      19114.12            1824.843333                  3  ...
# 2  Scientist      19114.12            1824.843333                  3  ...
# 3  Scientist      19114.12                    NaN                  3  ...
# 4    _______      34847.84            3037.986667                  2  ...
#
#    Num_Credit_Inquiries  Credit_Mix Outstanding_Debt Credit_Utilization_Ratio  \
# ...

# %%
print(df.tail())
# Out:
#             ID Customer_ID      Month            Name   Age          SSN  \
# 49995  0x25fe5  CUS_0x8600   December  Sarah McBridec  4975  031-35-0942
# 49996  0x25fee  CUS_0x942c  September           Nicks    25  078-73-5990
# 49997  0x25fef  CUS_0x942c    October           Nicks    25  078-73-5990
# 49998  0x25ff0  CUS_0x942c   November           Nicks    25  078-73-5990
# 49999  0x25ff1  CUS_0x942c   December           Nicks    25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 49995  Architect      20002.88            1929.906667                 10  ...
# 49996   Mechanic      39628.99                    NaN                  4  ...
# 49997   Mechanic      39628.99            3359.415833                  4  ...
# 49998   Mechanic      39628.99                    NaN                  4  ...
# 49999   Mechanic      39628.99            3359.415833                  4  ...
#
# ...

# %%
print(df.info())
#get a summary of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        50000 non-null  object
#  1   Customer_ID               50000 non-null  object
#  2   Month                     50000 non-null  object
#  3   Name                      44985 non-null  object
#  4   Age                       50000 non-null  object
#  5   SSN                       50000 non-null  object
#  6   Occupation                50000 non-null  object
#  7   Annual_Income             50000 non-null  object
#  8   Monthly_Inhand_Salary     42502 non-null  float64
#  9   Num_Bank_Accounts         50000 non-null  int64
#  10  Num_Credit_Card           50000 non-null  int64
#  11  Interest_Rate             50000 non-null  int64
#  12  Num_of_Loan               50000 non-null  object
# ...

# %%
print(df.shape)
#got the dimensions of the data
# Out:
# (50000, 27)

# %%
print(df.dtypes)
#checking the data types of each colunm
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                          object
# SSN                          object
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# ...

# %%
print(df.describe())
#descriptive analysis(exploration)
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count           42502.000000       50000.000000     50000.000000
# mean             4182.004291          16.838260        22.921480
# std              3174.109304         116.396848       129.314804
# min               303.645417          -1.000000         0.000000
# 25%              1625.188333           3.000000         4.000000
# 50%              3086.305000           6.000000         5.000000
# 75%              5934.189094           7.000000         7.000000
# max             15204.633333        1798.000000      1499.000000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count   50000.000000         50000.000000          48965.000000
# mean       68.772640            21.052640             30.080200
# std       451.602363            14.860397            196.984121
# min         1.000000            -5.000000              0.000000
# ...

# %%
print(df['Credit_Mix'].value_counts())
# Out:
# Credit_Mix
# Standard    18379
# Good        12260
# _            9805
# Bad          9556
# Name: count, dtype: int64

# %%
print(df['Num_Credit_Card'].value_counts())
# Out:
# Num_Credit_Card
# 5       9210
# 7       8271
# 6       8243
# 4       7072
# 3       6539
#         ...
# 662        1
# 445        1
# 78         1
# 1488       1
# 955        1
# Name: count, Length: 819, dtype: int64

# %%
print(df['Delay_from_due_date'].value_counts())
# Out:
# Delay_from_due_date
#  13    1761
#  15    1759
#  8     1680
#  9     1656
#  10    1645
#        ...
#  65      30
#  63      21
# -5       18
#  66      12
#  67       7
# Name: count, Length: 73, dtype: int64

# %%
print(df.isnull().sum())
#check for missing values
# Out:
# ID                             0
# Customer_ID                    0
# Month                          0
# Name                        5015
# Age                            0
# SSN                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary       7498
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                5704
# Delay_from_due_date            0
# Num_of_Delayed_Payment      3498
# Changed_Credit_Limit           0
# Num_Credit_Inquiries        1035
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          4470
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     2271
# Payment_Behaviour              0
# Monthly_Balance              562
# dtype: int64

# %%
import matplotlib.pyplot as plt
df['Credit_Mix'].hist()
#makes a histogram for numerical colunm
# Out:
# <Axes: >

# %%
df['Payment_of_Min_Amount'].hist()
# Out:
# <Axes: >

# %%
df['Annual_Income'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Annual_Income'>

# %%
df['Payment_Behaviour'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Payment_Behaviour'>

# %%
df['Month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %%
df['Num_of_Loan'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Payment_of_Min_Amount'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#multivariate analysis
#find relationship between colunms
df.plot.scatter(x='Delay_from_due_date', y='Num_Bank_Accounts')
# Out:
# <Axes: xlabel='Delay_from_due_date', ylabel='Num_Bank_Accounts'>

# %%
df.boxplot(column='Delay_from_due_date', by='Payment_Behaviour')
# x axis should be numerical colunm and y should be a gategorical data, so the boxplot can make sense.
# Out:
# <Axes: title={'center': 'Delay_from_due_date'}, xlabel='Payment_Behaviour'>

# %%
df.boxplot(column='Delay_from_due_date', by='Payment_of_Min_Amount')
# x axis should be numerical colunm and y should be a gategorical data, so the boxplot can make sense.
# Out:
# <Axes: title={'center': 'Delay_from_due_date'}, xlabel='Payment_of_Min_Amount'>

# %%
df.boxplot(column='Delay_from_due_date', by='Credit_Mix')
# x axis should be numerical colunm and y should be a gategorical data, so the boxplot can make sense.
# Out:
# <Axes: title={'center': 'Delay_from_due_date'}, xlabel='Credit_Mix'>

# %%
non_numeric_columns = df.select_dtypes(include=['object', 'category']).columns
print("Non-numeric columns:", non_numeric_columns)
# Out:
# Non-numeric columns: Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Num_of_Loan', 'Type_of_Loan',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Credit_Mix',
#        'Outstanding_Debt', 'Credit_History_Age', 'Payment_of_Min_Amount',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance'],
#       dtype='object')

# %%
non_numeric_columns = df.select_dtypes(include=['int']).columns
print("Non-numeric columns:", non_numeric_columns)
for col in non_numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')
dp =  df.select_dtypes(include=['int'])
# Out:
# Non-numeric columns: Index(['Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate',
#        'Delay_from_due_date'],
#       dtype='object')

# %%
print(dp)
# Out:
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date
# 0                      3                4              3                    3
# 1                      3                4              3                    3
# 2                      3                4              3                   -1
# 3                      3                4              3                    4
# 4                      2                4              6                    3
# ...                  ...              ...            ...                  ...
# 49995                 10                8             29                   33
# 49996                  4                6              7                   20
# 49997                  4                6              7                   23
# 49998                  4                6              7                   21
# 49999                  4                6              7                   22
#
# [50000 rows x 4 columns]

# %%
import numpy as np
corr_matrix = dp.corr()
print(corr_matrix)
#compute and visualize the co-relation matrix
#use only numeric colunms
# Out:
#                      Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  \
# Num_Bank_Accounts             1.000000         0.009091       0.002267
# Num_Credit_Card               0.009091         1.000000       0.000115
# Interest_Rate                 0.002267         0.000115       1.000000
# Delay_from_due_date           0.018402         0.009922       0.013543
#
#                      Delay_from_due_date
# Num_Bank_Accounts               0.018402
# Num_Credit_Card                 0.009922
# Interest_Rate                   0.013543
# Delay_from_due_date             1.000000

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
#visualize the numeric(int) data using heat map
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
sns.pairplot(df)
plt.show()
#explore pairwise relationships

# %%
sns.pairplot(dp)
plt.show()
#explore pairwise relationships
#creates a scatter plot of every colunms againest every other colunm(usually numerical)

# %%
# group = df.groupby('Delay_from_due_date').mean()
# print(group)
# #group by categorical colunm of choice
